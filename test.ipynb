# %%
import pandas as pd

# %%
df = pd.read_csv('~/data_files/brooklyn_sales_map.csv')
# Out:
# /var/folders/vh/d5t0x78n1vxdsryqryp4l95h0000gn/T/ipykernel_41063/3059615199.py:1: DtypeWarning: Columns (40,41,43,45,46,47,86) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('~/data_files/brooklyn_sales_map.csv')

# %%
df.shape
# Out:
# (390883, 111)

# %%
df.head()
# Out:
#    Unnamed: 0  borough           neighborhood building_class_category  \
# 0           1        3     DOWNTOWN-METROTECH   28  COMMERCIAL CONDOS
# 1           2        3  DOWNTOWN-FULTON FERRY  29  COMMERCIAL GARAGES
# 2           3        3       BROOKLYN HEIGHTS    21  OFFICE BUILDINGS
# 3           4        3             MILL BASIN     22  STORE BUILDINGS
# 4           5        3       BROOKLYN HEIGHTS         26 OTHER HOTELS
#
#   tax_class  block   lot  easement building_class              address  ...  \
# 0         4    140  1001       NaN             R5       330 JAY STREET  ...
# 1         4     54     1       NaN             G7        85 JAY STREET  ...
# 2         4    204     1       NaN             O6  29 COLUMBIA HEIGHTS  ...
# 3         4   8470    55       NaN             K6        5120 AVENUE U  ...
# 4         4    230     1       NaN             H8      21 CLARK STREET  ...
#
#   EDesigNum        APPBBL     APPDate  PLUTOMapID  FIRM07_FLA  PFIRM15_FL  \
# ...

# %%
data = [
    {
        "location_name": "Checkpoint Alpha",
        "mgrs": "33TWN8846537798",
        "latitude": 48.8582,
        "longitude": 2.2945,
        "easting": 488465,
        "northing": 5377984,
        "utm_zone": "33T"
    },
    {
        "location_name": "Base Bravo",
        "mgrs": "38SMB4488049888",
        "latitude": 21.4225,
        "longitude": 39.8262,
        "easting": 444880,
        "northing": 2379888,
        "utm_zone": "38S"
    },
    {
        "location_name": "Outpost Charlie",
        "mgrs": "32TLT9329272460",
        "latitude": 52.5163,
        "longitude": 13.3777,
        "easting": 493292,
        "northing": 5824600,
        "utm_zone": "32T"
    },
    {
        "location_name": "Observation Delta",
        "mgrs": "36SYC9469640184",
        "latitude": 24.7743,
        "longitude": 46.7386,
        "easting": 694696,
        "northing": 2740184,
        "utm_zone": "36S"
    }
]

df = pd.DataFrame(data)

# %%
df
# Out:
#        location_name             mgrs  latitude  longitude  easting  northing  \
# 0   Checkpoint Alpha  33TWN8846537798   48.8582     2.2945   488465   5377984
# 1         Base Bravo  38SMB4488049888   21.4225    39.8262   444880   2379888
# 2    Outpost Charlie  32TLT9329272460   52.5163    13.3777   493292   5824600
# 3  Observation Delta  36SYC9469640184   24.7743    46.7386   694696   2740184
#
#   utm_zone
# 0      33T
# 1      38S
# 2      32T
# 3      36S
